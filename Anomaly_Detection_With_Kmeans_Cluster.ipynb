# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
import pickle as pkl
from flask import Flask
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:49
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "c:\Users\sapyy\anaconda3\python.exe"
#   * The NumPy version is: "1.24.4"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:49
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "c:\Users\sapyy\anaconda3\python.exe"
#   * The NumPy version is: "1.24.4"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:49
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "c:\Users\sapyy\anaconda3\python.exe"
#   * The NumPy version is: "1.24.4"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:49
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "c:\Users\sapyy\anaconda3\python.exe"
#   * The NumPy version is: "1.24.4"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File c:\Users\sapyy\anaconda3\Lib\site-packages\numpy\_core\__init__.py:49
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "c:\Users\sapyy\anaconda3\python.exe"
#   * The NumPy version is: "1.24.4"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       3 import numpy as np
#       4 import seaborn as sns
# ----> 5 from sklearn.cluster import KMeans
#       6 import pickle as pkl
#       7 from flask import Flask
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\sklearn\__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
#      71     # process, as it may not be compiled yet
#      72 else:
#    (...)
#      78     # later is linked to the OpenMP runtime to make it possible to introspect
#      79     # it and importing it first would fail if the OpenMP dll cannot be found.
#      80     from . import (
#      81         __check_build,  # noqa: F401
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      87     __all__ = [
#      88         "calibration",
#      89         "cluster",
#    (...)
#     130         "show_versions",
#     131     ]
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\sklearn\utils\__init__.py:11
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      14 # Make _safe_indexing importable from here for backward compat as this particular
#      15 # helper is considered semi-private and typically very useful for third-party
#      16 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      17 # _safe_indexing was included in our public API documentation despite the leading
#      18 # `_` in its name.
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\sklearn\utils\_chunking.py:8
#       5 import numpy as np
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#      11 def chunk_generator(gen, chunksize):
#      12     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      13     chunk may have a length less than ``chunksize``."""
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:11
#       8 from numbers import Integral, Real
#      10 import numpy as np
# ---> 11 from scipy.sparse import csr_matrix, issparse
#      13 from .._config import config_context, get_config
#      14 from .validation import _is_arraylike_not_scalar
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\scipy\sparse\__init__.py:294
#     291 import warnings as _warnings
#     293 from ._base import *
# --> 294 from ._csr import *
#     295 from ._csc import *
#     296 from ._lil import *
#
# File c:\Users\sapyy\anaconda3\Lib\site-packages\scipy\sparse\_csr.py:11
#       9 from ._matrix import spmatrix
#      10 from ._base import _spbase, sparray
# ---> 11 from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
#      12                            get_csr_submatrix)
#      13 from ._sputils import upcast
#      15 from ._compressed import _cs_matrix
#
# ImportError: numpy._core.multiarray failed to import

# %%
df = pd.read_csv('Dataset_limonia.csv')

# %%
df.head()
# Out:
#         Suhu        pH    Amonia
# 0  30.126294  6.776223  0.490119
# 1  27.409527  6.022236  0.616030
# 2  25.238164  6.587337  0.415515
# 3  24.988726  6.743567  0.410149
# 4  26.350025  8.721770  0.599397

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

def plot_sensor(title, n_sample=None, bottom_n=0):
    if n_sample is None:
        n_sample = int((df.shape[0]-1)*1)
    print(type(n_sample))

    plt.figure(figsize=(16, 5))
    plt.plot(pd.RangeIndex(len(df)), df.Suhu, color='#F7DC6F', label='Sensor Suhu')
    plt.plot(pd.RangeIndex(len(df)), df.pH, color='#8E44AD', label='Sensor pH')
    plt.plot(pd.RangeIndex(len(df)), df.Amonia, color='#16A085', label='Sensor Amonia')

    plt.tick_params(axis='y', labelsize=18)
    plt.tick_params(axis='x', labelsize=18)
    plt.ylabel('Values', fontsize=21)
    plt.xlabel('Sample Index', fontsize=21)
    plt.xlim(bottom_n, n_sample)
    plt.ylim(min(df[['Suhu', 'pH', 'Amonia']][bottom_n:n_sample].min()),
             max(df[['Suhu', 'pH', 'Amonia']][bottom_n:n_sample].max()))

    plt.suptitle(title, fontsize=20, y=0.94, fontweight='heavy')

    leg = plt.legend(loc='best', ncol=1, prop={'size': 14, 'weight': 'bold'})

    for i in range(3):
        leg.get_lines()[i].set_linewidth(12)

plot_sensor('Plot Sensors')
plot_sensor('Plot Sensors (Zoomed)', 500, 100)
plt.show()
# Out:
# <class 'int'>
# <class 'int'>

# %%
df.head()
# Out:
#         Suhu        pH    Amonia
# 0  30.126294  6.776223  0.490119
# 1  27.409527  6.022236  0.616030
# 2  25.238164  6.587337  0.415515
# 3  24.988726  6.743567  0.410149
# 4  26.350025  8.721770  0.599397

# %%
df.describe(percentiles=[.005,.01,.25,.5,.75,.8,.99,.995])
# Out:
#                 Suhu             pH         Amonia
# count  100000.000000  100000.000000  100000.000000
# mean       27.245940       7.076150       0.420416
# std         2.043823       0.761396       0.230027
# min        22.018569       5.302238       0.000015
# 0.5%       22.578560       5.464904       0.007346
# 1%         22.796061       5.536393       0.014478
# 25%        25.821512       6.516437       0.223177
# 50%        27.246521       7.075251       0.421374
# 75%        28.747089       7.614291       0.617081
# 80%        29.121738       7.749900       0.656449
# 99%        31.366941       8.722296       0.832941
# 99.5%      31.547426       8.806616       0.850445
# max        31.984582       8.988338       0.889358

# %%
df.isna().sum()
# Out:
# Suhu      0
# pH        0
# Amonia    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Suhu    100000 non-null  float64
#  1   pH      100000 non-null  float64
#  2   Amonia  100000 non-null  float64
# dtypes: float64(3)
# memory usage: 2.3 MB

# %%
df.hist(bins = 100, figsize=(20, 15), color = 'brown');

# %%
def apply_thresholds(df):
    # Example usage:
    column_thresholds = {
        'Suhu': (25.0, 30.0),
        'pH': (6.0, 9.0),
        'Amonia': (0.0, 0.8)
    }
    for column, thresholds in column_thresholds.items():
        lower_bound, upper_bound = thresholds
        df[f'{column}_thresholded'] = df[column].apply(lambda val: 1 if val > upper_bound or val < lower_bound else 0)
    return df
def get_pattern(raw_features):
    pattern_binary = ''
    pattern_readable = ''

    for i in range(3):
        if raw_features[i+3] == 1:
            pattern_readable += raw_features.keys()[i] + ': Failure, '
        else:
            pattern_readable += raw_features.keys()[i] + ': Normal, '
        pattern_binary += str(int(raw_features[i+3]))

    return pattern_binary, pattern_readable

# %%
# Assuming df is your DataFrame, you can call the function like this:
df = apply_thresholds(df)

# %%
df
# Out:
#             Suhu        pH    Amonia  Suhu_thresholded  pH_thresholded  \
# 0      30.126294  6.776223  0.490119                 1               0
# 1      27.409527  6.022236  0.616030                 0               0
# 2      25.238164  6.587337  0.415515                 0               0
# 3      24.988726  6.743567  0.410149                 1               0
# 4      26.350025  8.721770  0.599397                 0               0
# ...          ...       ...       ...               ...             ...
# 99995  27.544469  5.770719  0.017776                 0               1
# 99996  26.815925  5.935865  0.111814                 0               1
# 99997  25.865077  7.258267  0.074577                 0               0
# 99998  29.337515  7.687543  0.354566                 0               0
# 99999  27.731402  7.646908  0.226670                 0               0
#
#        Amonia_thresholded
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 99995                   0
# 99996                   0
# 99997                   0
# 99998                   0
# 99999                   0
#
# [100000 rows x 6 columns]

# %%
df.head(3)
# Out:
#         Suhu        pH    Amonia  Suhu_thresholded  pH_thresholded  \
# 0  30.126294  6.776223  0.490119                 1               0
# 1  27.409527  6.022236  0.616030                 0               0
# 2  25.238164  6.587337  0.415515                 0               0
#
#    Amonia_thresholded
# 0                   0
# 1                   0
# 2                   0

# %%
df.tail(3)
# Out:
#             Suhu        pH    Amonia  Suhu_thresholded  pH_thresholded  \
# 99997  25.865077  7.258267  0.074577                 0               0
# 99998  29.337515  7.687543  0.354566                 0               0
# 99999  27.731402  7.646908  0.226670                 0               0
#
#        Amonia_thresholded
# 99997                   0
# 99998                   0
# 99999                   0

# %%
df.nunique()
# Out:
# Suhu                  100000
# pH                    100000
# Amonia                100000
# Suhu_thresholded           2
# pH_thresholded             2
# Amonia_thresholded         2
# dtype: int64

# %%
print("Missing values:\n", df[df.columns[3:6]].isnull().sum())
print("Infinite values:\n", np.isinf(df[df.columns[3:6]]).sum())
# Out:
# Missing values:
#  Suhu_thresholded      0
# pH_thresholded        0
# Amonia_thresholded    0
# dtype: int64
# Infinite values:
#  Suhu_thresholded      0
# pH_thresholded        0
# Amonia_thresholded    0
# dtype: int64

# %%
print(df[df.columns[3:6]])
# Out:
#        Suhu_thresholded  pH_thresholded  Amonia_thresholded
# 0                     1               0                   0
# 1                     0               0                   0
# 2                     0               0                   0
# 3                     1               0                   0
# 4                     0               0                   0
# ...                 ...             ...                 ...
# 99995                 0               1                   0
# 99996                 0               1                   0
# 99997                 0               0                   0
# 99998                 0               0                   0
# 99999                 0               0                   0
#
# [100000 rows x 3 columns]

# %%
from kmodes.kmodes import KModes

# %%
data = df[df.columns[3:6]]

# Use KModes for clustering
cls = KModes(n_clusters=2, init='Huang', n_init=50, verbose=1)
df['Condition'] = cls.fit_predict(data)
print(df['Condition'].value_counts())
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 6, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 7, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 8, iteration: 1/100, moves: 0, cost: 11408.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 9, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 10, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 11, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 12, iteration: 1/100, moves: 0, cost: 11408.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 13, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 14, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 15, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 16, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 17, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 18, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 19, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 20, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 21, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 22, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 23, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 24, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 25, iteration: 1/100, moves: 0, cost: 33863.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 26, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 27, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 28, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 29, iteration: 1/100, moves: 0, cost: 32233.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 30, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 31, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 32, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 33, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 34, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 35, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 36, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 37, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 38, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 39, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 40, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 41, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 42, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 43, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 44, iteration: 1/100, moves: 0, cost: 11408.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 45, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 46, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 47, iteration: 1/100, moves: 626, cost: 33863.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 48, iteration: 1/100, moves: 2088, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 49, iteration: 1/100, moves: 0, cost: 27547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 50, iteration: 1/100, moves: 0, cost: 27547.0
# Best run was number 8
# 1    74999
# 0    25001
# Name: Condition, dtype: int64

# %%
df['Binary Pattern'], df['Readable Pattern'] = zip(*df.apply(get_pattern, axis=1))

# %%
from sklearn.metrics import silhouette_score
print(silhouette_score(df[df.columns[3:6]], cls.labels_))
# Out:
# 0.8285809986871486

# %%
df.Amonia_thresholded.value_counts(), df.pH_thresholded.value_counts(), df.Suhu_thresholded.value_counts()
# Out:
# (0    97454
#  1     2546
#  Name: Amonia_thresholded, dtype: int64,
#  0    91138
#  1     8862
#  Name: pH_thresholded, dtype: int64,
#  0    74999
#  1    25001
#  Name: Suhu_thresholded, dtype: int64)

# %%
with open('./API/'+'cluster_model.pkl', 'wb') as f:
  pkl.dump(cls, f, pkl.HIGHEST_PROTOCOL)

# %%
df
# Out:
#             Suhu        pH    Amonia  Suhu_thresholded  pH_thresholded  \
# 0      30.126294  6.776223  0.490119                 1               0
# 1      27.409527  6.022236  0.616030                 0               0
# 2      25.238164  6.587337  0.415515                 0               0
# 3      24.988726  6.743567  0.410149                 1               0
# 4      26.350025  8.721770  0.599397                 0               0
# ...          ...       ...       ...               ...             ...
# 99995  27.544469  5.770719  0.017776                 0               1
# 99996  26.815925  5.935865  0.111814                 0               1
# 99997  25.865077  7.258267  0.074577                 0               0
# 99998  29.337515  7.687543  0.354566                 0               0
# 99999  27.731402  7.646908  0.226670                 0               0
#
#        Amonia_thresholded  Condition Binary Pattern  \
# 0                       0          0            100
# 1                       0          1            000
# 2                       0          1            000
# 3                       0          0            100
# 4                       0          1            000
# ...                   ...        ...            ...
# 99995                   0          1            010
# 99996                   0          1            010
# 99997                   0          1            000
# 99998                   0          1            000
# 99999                   0          1            000
#
#                                   Readable Pattern
# 0      Suhu: Failure, pH: Normal, Amonia: Normal,
# 1       Suhu: Normal, pH: Normal, Amonia: Normal,
# 2       Suhu: Normal, pH: Normal, Amonia: Normal,
# 3      Suhu: Failure, pH: Normal, Amonia: Normal,
# 4       Suhu: Normal, pH: Normal, Amonia: Normal,
# ...                                            ...
# 99995  Suhu: Normal, pH: Failure, Amonia: Normal,
# 99996  Suhu: Normal, pH: Failure, Amonia: Normal,
# 99997   Suhu: Normal, pH: Normal, Amonia: Normal,
# 99998   Suhu: Normal, pH: Normal, Amonia: Normal,
# 99999   Suhu: Normal, pH: Normal, Amonia: Normal,
#
# [100000 rows x 9 columns]

# %%
df['Condition'].value_counts()
# Out:
# 1    74999
# 0    25001
# Name: Condition, dtype: int64

# %%
df['Binary Pattern'].value_counts()
# Out:
# 000    66482
# 100    22344
# 010     6597
# 110     2031
# 001     1743
# 101      569
# 011      177
# 111       57
# Name: Binary Pattern, dtype: int64

# %%
df['Readable Pattern'].value_counts()
# Out:
# Suhu: Normal, pH: Normal, Amonia: Normal,        66482
# Suhu: Failure, pH: Normal, Amonia: Normal,       22344
# Suhu: Normal, pH: Failure, Amonia: Normal,        6597
# Suhu: Failure, pH: Failure, Amonia: Normal,       2031
# Suhu: Normal, pH: Normal, Amonia: Failure,        1743
# Suhu: Failure, pH: Normal, Amonia: Failure,        569
# Suhu: Normal, pH: Failure, Amonia: Failure,        177
# Suhu: Failure, pH: Failure, Amonia: Failure,        57
# Name: Readable Pattern, dtype: int64

# %%
import pickle

rules_model = []
alert_rules = []

for pattern in df[df.Condition==1]['Binary Pattern'].value_counts().keys():
  rules_model.append(pattern)
for pattern in df[df.Condition==1]['Readable Pattern'].value_counts().keys():
  alert_rules.append(pattern+' -> Kualitas Air Tidak Baik !')

with open('./API/'+'rules_model.pkl', 'wb') as f:
  pickle.dump(rules_model, f, pickle.HIGHEST_PROTOCOL)
with open('./API/'+'alert_rules.pkl', 'wb') as f:
  pickle.dump(alert_rules, f, pickle.HIGHEST_PROTOCOL)

alert_rules
# Out:
# ['Suhu: Normal, pH: Normal, Amonia: Normal,  -> Kualitas Air Tidak Baik !',
#  'Suhu: Normal, pH: Failure, Amonia: Normal,  -> Kualitas Air Tidak Baik !',
#  'Suhu: Normal, pH: Normal, Amonia: Failure,  -> Kualitas Air Tidak Baik !',
#  'Suhu: Normal, pH: Failure, Amonia: Failure,  -> Kualitas Air Tidak Baik !']

# %%
df[df.Condition==0]['Binary Pattern'].value_counts()
# Out:
# 100    22344
# 110     2031
# 101      569
# 111       57
# Name: Binary Pattern, dtype: int64

# %%
rules_model
# Out:
# ['000', '010', '001', '011']

# %%
alert_rules
# Out:
# ['Suhu: Normal, pH: Normal, Amonia: Normal,  -> Kualitas Air Tidak Baik !',
#  'Suhu: Normal, pH: Failure, Amonia: Normal,  -> Kualitas Air Tidak Baik !',
#  'Suhu: Normal, pH: Normal, Amonia: Failure,  -> Kualitas Air Tidak Baik !',
#  'Suhu: Normal, pH: Failure, Amonia: Failure,  -> Kualitas Air Tidak Baik !']
